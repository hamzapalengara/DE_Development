# %%
import sys
if "/mnt/c/Users/HP/Learning/DE_Development" not in sys.path:
    sys.path.append("/mnt/c/Users/HP/Learning/DE_Development")

# %%
from pyspark.sql import functions as F, types as T
from pyspark.sql import SparkSession
import yaml, os, sys
from src.utils.spark_utils import create_spark


    
config_path = '/mnt/c/Users/HP/Learning/DE_Development/config/pipeline_config_wsl.yaml'

with open(config_path, "r") as f:
    config_file = yaml.safe_load(f)

base_path = config_file["paths"]["base_path"]
print(base_path)
landing_batch = config_file["paths"]["landing"]["batch"].replace("${paths.base_path}", base_path)
landing_batch_product = os.path.join(landing_batch, "Products.csv")
print(landing_batch_product)
bronze_products_path = config_file["paths"]["bronze"]["products"].replace("${paths.base_path}", base_path)
print(bronze_products_path)

spark = create_spark(config_file["spark"]["app_name"], config_file["spark"]["configs"])



# Define schema matching your actual columns
products_schema = T.StructType([
    T.StructField("product_id", T.StringType(), True),
    T.StructField("product_name", T.StringType(), True),
    T.StructField("category", T.StringType(), True),
    T.StructField("sub_category", T.StringType(), True),
    T.StructField("brand", T.StringType(), True),
    T.StructField("unit_price", T.DoubleType(), True),
    T.StructField("launch_date", T.StringType(), True),  # Keep as string, convert later
    T.StructField("is_active", T.BooleanType(), True),
])


product_raw = (spark.read
    .option("header", True)
    .schema(products_schema)
    .csv(landing_batch_product))
product_raw.show(5)



product_bronze = (product_raw
                  .withColumn("ingestion_timestamp", F.current_timestamp())
                  .withColumn("source_file", F.input_file_name())
                  .withColumn("batch_date", F.current_date())
                  .withColumn("record_hash", F.sha2(F.concat_ws("||", *[F.coalesce(F.col(c).cast("string"), F.lit("")) for c in product_raw.columns]), 256)))

# Basic DQ: required fields not null, positive price
required_cols = [F.col("product_id").isNotNull(), F.col("product_name").isNotNull()]
dq_conditions = required_cols + [(F.col("unit_price").isNull()) | (F.col("unit_price") >= F.lit(0.0))]
dq_valid = (F.col("product_id").isNotNull() & 
            F.col("product_name").isNotNull() & 
            ((F.col("unit_price").isNull()) | (F.col("unit_price") >= F.lit(0.0))))

product_bronze = product_bronze.withColumn("dq_is_valid", dq_valid)


product_bronze.show(5, truncate = False)


(product_bronze
  .repartition(1)
  .write
  .mode("overwrite")
  .partitionBy("batch_date")
  .parquet(bronze_products_path))

# Read the written Parquet data back
bronze_products_read = spark.read.parquet(bronze_products_path)
print("=== BRONZE DATA READ BACK ===")
bronze_products_read.show(10, truncate=False)
print(f"Total rows in bronze: {bronze_products_read.count()}")
# Out:
# /mnt/c/Users/HP/Learning/DE_Development
# /mnt/c/Users/HP/Learning/DE_Development/data/landing/batch/Products.csv
# /mnt/c/Users/HP/Learning/DE_Development/data/bronze/products
# +----------+--------------------+---------+------------+------------+----------+-----------+---------+
# |product_id|        product_name| category|sub_category|       brand|unit_price|launch_date|is_active|
# +----------+--------------------+---------+------------+------------+----------+-----------+---------+
# |      P001|       Tata Tea Gold|Beverages|         Tea|    Tata Tea|     245.0| 15-01-2020|     true|
# |      P002|   Tata Coffee Grand|Beverages|      Coffee| Tata Coffee|     185.0| 10-06-2019|     true|
# |      P003|Tata Sampann Toor...|    Foods|      Pulses|Tata Sampann|     145.0| 20-03-2021|     true|
# |      P004|      Tata Salt Lite|    Foods|        Salt|   Tata Salt|      28.0| 12-04-2018|     true|
# |      P005|    Tetley Green Tea|Beverages|         Tea|      Tetley|     120.0| 05-11-2020|     true|
# +----------+--------------------+---------+------------+------------+----------+-----------+---------+
# only showing top 5 rows
# +----------+---------------------+---------+------------+------------+----------+-----------+---------+--------------------------+------------------------------------------------------------------------------+----------+----------------------------------------------------------------+-----------+
# |product_id|product_name         |category |sub_category|brand       |unit_price|launch_date|is_active|ingestion_timestamp       |source_file                                                                   |batch_date|record_hash                                                     |dq_is_valid|
# +----------+---------------------+---------+------------+------------+----------+-----------+---------+--------------------------+------------------------------------------------------------------------------+----------+----------------------------------------------------------------+-----------+
# |P001      |Tata Tea Gold        |Beverages|Tea         |Tata Tea    |245.0     |15-01-2020 |true     |2025-09-04 16:56:07.181744|file:///mnt/c/Users/HP/Learning/DE_Development/data/landing/batch/Products.csv|2025-09-04|6ccaacf03382688339726e720e09b053fb1f0facc75c733426e10106861036ff|true       |
# |P002      |Tata Coffee Grand    |Beverages|Coffee      |Tata Coffee |185.0     |10-06-2019 |true     |2025-09-04 16:56:07.181744|file:///mnt/c/Users/HP/Learning/DE_Development/data/landing/batch/Products.csv|2025-09-04|33ad935f2f44b5b39c9d289ded884d88cf9cea4e07b123df8513969c2bbe9baa|true       |
# |P003      |Tata Sampann Toor Dal|Foods    |Pulses      |Tata Sampann|145.0     |20-03-2021 |true     |2025-09-04 16:56:07.181744|file:///mnt/c/Users/HP/Learning/DE_Development/data/landing/batch/Products.csv|2025-09-04|2144b8ac1c6e39ad59a921a17566caa5844090956c1f6645321517fd713c91ca|true       |
# |P004      |Tata Salt Lite       |Foods    |Salt        |Tata Salt   |28.0      |12-04-2018 |true     |2025-09-04 16:56:07.181744|file:///mnt/c/Users/HP/Learning/DE_Development/data/landing/batch/Products.csv|2025-09-04|31c62740cbbe529d119f4934e8e502f582372377b42d19f22a3c280ebb8f5c8a|true       |
# |P005      |Tetley Green Tea     |Beverages|Tea         |Tetley      |120.0     |05-11-2020 |true     |2025-09-04 16:56:07.181744|file:///mnt/c/Users/HP/Learning/DE_Development/data/landing/batch/Products.csv|2025-09-04|6b0d1df627cbdeb5b81988962d7d070e7a4e3ec52ecb3e80238fe2fd58c72fe6|true       |
# +----------+---------------------+---------+------------+------------+----------+-----------+---------+--------------------------+------------------------------------------------------------------------------+----------+----------------------------------------------------------------+-----------+
# only showing top 5 rows
# === BRONZE DATA READ BACK ===
# +----------+--------------------------+---------+------------+-------------+----------+-----------+---------+--------------------------+------------------------------------------------------------------------------+----------------------------------------------------------------+-----------+----------+
# |product_id|product_name              |category |sub_category|brand        |unit_price|launch_date|is_active|ingestion_timestamp       |source_file                                                                   |record_hash                                                     |dq_is_valid|batch_date|
# +----------+--------------------------+---------+------------+-------------+----------+-----------+---------+--------------------------+------------------------------------------------------------------------------+----------------------------------------------------------------+-----------+----------+
# |P001      |Tata Tea Gold             |Beverages|Tea         |Tata Tea     |245.0     |15-01-2020 |true     |2025-09-04 16:56:07.323327|file:///mnt/c/Users/HP/Learning/DE_Development/data/landing/batch/Products.csv|6ccaacf03382688339726e720e09b053fb1f0facc75c733426e10106861036ff|true       |2025-09-04|
# |P002      |Tata Coffee Grand         |Beverages|Coffee      |Tata Coffee  |185.0     |10-06-2019 |true     |2025-09-04 16:56:07.323327|file:///mnt/c/Users/HP/Learning/DE_Development/data/landing/batch/Products.csv|33ad935f2f44b5b39c9d289ded884d88cf9cea4e07b123df8513969c2bbe9baa|true       |2025-09-04|
# |P003      |Tata Sampann Toor Dal     |Foods    |Pulses      |Tata Sampann |145.0     |20-03-2021 |true     |2025-09-04 16:56:07.323327|file:///mnt/c/Users/HP/Learning/DE_Development/data/landing/batch/Products.csv|2144b8ac1c6e39ad59a921a17566caa5844090956c1f6645321517fd713c91ca|true       |2025-09-04|
# |P004      |Tata Salt Lite            |Foods    |Salt        |Tata Salt    |28.0      |12-04-2018 |true     |2025-09-04 16:56:07.323327|file:///mnt/c/Users/HP/Learning/DE_Development/data/landing/batch/Products.csv|31c62740cbbe529d119f4934e8e502f582372377b42d19f22a3c280ebb8f5c8a|true       |2025-09-04|
# |P005      |Tetley Green Tea          |Beverages|Tea         |Tetley       |120.0     |05-11-2020 |true     |2025-09-04 16:56:07.323327|file:///mnt/c/Users/HP/Learning/DE_Development/data/landing/batch/Products.csv|6b0d1df627cbdeb5b81988962d7d070e7a4e3ec52ecb3e80238fe2fd58c72fe6|true       |2025-09-04|
# |P006      |Tata Sampann Chilli Powder|Foods    |Spices      |Tata Sampann |65.0      |18-07-2021 |true     |2025-09-04 16:56:07.323327|file:///mnt/c/Users/HP/Learning/DE_Development/data/landing/batch/Products.csv|27f407fc472e2107600d7254e39056f42e0401b08f6b1d202c4d35d007b53b65|true       |2025-09-04|
# |P007      |Eight O'Clock Coffee      |Beverages|Coffee      |Eight O'Clock|320.0     |28-02-2022 |true     |2025-09-04 16:56:07.323327|file:///mnt/c/Users/HP/Learning/DE_Development/data/landing/batch/Products.csv|5a287b461f18b585d6b4ee8183783176a8294351961bf4afd482acdfa1e85389|true       |2025-09-04|
# |P008      |Himalayan Natural Water   |Beverages|Water       |Himalayan    |20.0      |15-09-2019 |true     |2025-09-04 16:56:07.323327|file:///mnt/c/Users/HP/Learning/DE_Development/data/landing/batch/Products.csv|2fd12783f63648009c56f2a96b004dfc5fbe0ef9af9b8a6680501fc3bccd1faf|true       |2025-09-04|
# |P009      |Tata Soulfull Ragi Bites  |Foods    |Snacks      |Tata Soulfull|40.0      |10-05-2022 |true     |2025-09-04 16:56:07.323327|file:///mnt/c/Users/HP/Learning/DE_Development/data/landing/batch/Products.csv|3fc28c22cdfa4d6b364d50b27f42db25c454f585e16ac56a18f2a95e61114c6a|true       |2025-09-04|
# |P010      |Tata Tea Premium          |Beverages|Tea         |Tata Tea     |152.0     |01-01-2015 |true     |2025-09-04 16:56:07.323327|file:///mnt/c/Users/HP/Learning/DE_Development/data/landing/batch/Products.csv|156aa1b916f052f6d046dcf397558b7d257a05392aa7cda7773ed58028abafca|true       |2025-09-04|
# +----------+--------------------------+---------+------------+-------------+----------+-----------+---------+--------------------------+------------------------------------------------------------------------------+----------------------------------------------------------------+-----------+----------+
#
# Total rows in bronze: 10
